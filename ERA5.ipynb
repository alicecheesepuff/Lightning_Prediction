# %%
import xarray as xr

store1 = 'gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3'
ds1 = xr.open_dataset(store1, engine='zarr', chunks={})

# %%
display(ds1.head())
# Out:
# <xarray.Dataset> Size: 159kB
# Dimensions:                                                          (time: 5,
#                                                                       latitude: 5,
#                                                                       longitude: 5,
#                                                                       level: 5)
# Coordinates:
#   * latitude                                                         (latitude) float32 20B ...
#   * level                                                            (level) int64 40B ...
#   * longitude                                                        (longitude) float32 20B ...
#   * time                                                             (time) datetime64[ns] 40B ...
# Data variables: (12/273)
#     100m_u_component_of_wind                                         (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     100m_v_component_of_wind                                         (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     10m_u_component_of_neutral_wind                                  (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     10m_u_component_of_wind                                          (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     10m_v_component_of_neutral_wind                                  (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     10m_v_component_of_wind                                          (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     ...                                                               ...
#     wave_spectral_directional_width_for_swell                        (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     wave_spectral_directional_width_for_wind_waves                   (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     wave_spectral_kurtosis                                           (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     wave_spectral_peakedness                                         (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     wave_spectral_skewness                                           (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
#     zero_degree_level                                                (time, latitude, longitude) float32 500B dask.array<chunksize=(1, 5, 5), meta=np.ndarray>
# Attributes:
#     last_updated:           2025-11-14 01:55:22.030606+00:00
#     valid_time_start:       1940-01-01
#     valid_time_stop:        2025-04-30
#     valid_time_stop_era5t:  2025-11-08

# %%
store2 = 'gs://gcp-public-data-arco-era5/ar/model-level-1h-0p25deg.zarr-v1'
ds2 = xr.open_dataset(store2, engine='zarr', chunks={})
